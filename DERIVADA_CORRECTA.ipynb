# %% [markdown]
# <a href="https://colab.research.google.com/github/EmmanuelPaz43/Clase_Derivadas/blob/main/DERIVADA_CORRECTA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Graficar derivada de la función del movimiento armónico
# Autor: Paz Córdova Emmanuel
#Fecha: Septiembre 2, 2021

import matplotlib.pyplot as plt
import numpy as np 
import math

def f1(A, P, t):
    return A*np.sin((2*np.pi/P)*t)

def f2(A, P, texa):
    return A*(2*np.pi/P)*np.cos((2*np.pi/P)*texa)      

#t1=np.arange(0, 10.00, 0.1)                  

A=float(input("Ingrese la amplitud del oscilador en metros: "))
T=float(input("Ingrese el periodo del oscilador en segundos: "))
t_exacto=float(input("Ingrese el punto del tiempo en segundos donde quiere calcular la derivada: "))
h=float(input("Ingrese el valor del incremento: "))

print("La derivada numérica de la función en el punto dado es: ", (f1(A, T, t_exacto+h)-f1(A, T, t_exacto))/h)
print("Derivada exacta: ", f2(A, T, t_exacto))

plt.plot(t1, f1(A, T, t1)) # Función Original
plt.plot(t1, (f1(A, T, t1+h)-f1(A, T, t1))/h) #Derivada Numérica
plt.plot(t1, f2(A, T, t1)) #Derivada Exacta
plt.show()
# Out:
# Ingrese la amplitud del oscilador en metros: 5
# Ingrese el periodo del oscilador en segundos: 2
# Ingrese el punto del tiempo en segundos donde quiere calcular la derivada: 3
# Ingrese el valor del incremento: 0.5
# La derivada numérica de la función en el punto dado es:  -10.000000000000004
# Derivada exacta:  -15.707963267948966
